# %% [markdown]
# # COVID-19 DATA VISUALIZATION
#
# #### In this dataset, I will be doing data visualizations on COVID-19 data. Global confirmed, recovered, and death cases data is visualized.  Data is obtained from CSSEGIS (John Hopkins University).
# ##### Dataset repository: https://github.com/CSSEGISandData/COVID-19/tree/master/csse_covid_19_data/csse_covid_19_time_series

# %%
import pandas as pd # Importing necessary libraries
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import folium

# %% [markdown]
# ## Getting the data

# %%
url = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv'
confirmed = pd.read_csv(url)
url = 'https://github.com/CSSEGISandData/COVID-19/raw/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv'
recovered = pd.read_csv(url)
url = 'https://github.com/CSSEGISandData/COVID-19/raw/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv'
deaths = pd.read_csv(url)
confirmed.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  5/29/22  5/30/22  5/31/22  6/1/22  \
# 0        0        0        0        0  ...   180174   180259   180347  180419
# 1        0        0        0        0  ...   276101   276101   276101  276221
# 2        0        0        0        0  ...   265873   265877   265884  265887
# 3        0        0        0        0  ...    42894    42894    42894   42894
# 4        0        0        0        0  ...    99527    99761    99761   99761
#
#    6/2/22  6/3/22  6/4/22  6/5/22  6/6/22  6/7/22
# 0  180520  180584  180615  180615  180688  180741
# 1  276221  276310  276342  276401  276415  276468
# 2  265889  265889  265889  265897  265900  265904
# 3   42894   43067   43067   43067   43067   43067
# 4   99761   99761   99761   99761   99761   99761
#
# [5 rows x 872 columns]

# %% [markdown]
# We can see real time daily data is updated along the columns, country/region data are sorted in alphabetical order and there's data on latitude & longitude of each regions.

# %% [markdown]
# ## Reformatting

# %% [markdown]
# As observed above, we can simplify the column names to make it easier to work with.

# %%
datasets = [confirmed, recovered, deaths]

for df in datasets:
    df.rename(columns={'Province/State':'state',
                       'Country/Region':'country', 
                       'Lat':'lat', 'Long':'long'}, inplace=True)
deaths.head()
# Out:
#   state      country       lat       long  1/22/20  1/23/20  1/24/20  1/25/20  \
# 0   NaN  Afghanistan  33.93911  67.709953        0        0        0        0
# 1   NaN      Albania  41.15330  20.168300        0        0        0        0
# 2   NaN      Algeria  28.03390   1.659600        0        0        0        0
# 3   NaN      Andorra  42.50630   1.521800        0        0        0        0
# 4   NaN       Angola -11.20270  17.873900        0        0        0        0
#
#    1/26/20  1/27/20  ...  5/29/22  5/30/22  5/31/22  6/1/22  6/2/22  6/3/22  \
# 0        0        0  ...     7701     7701     7705    7707    7708    7708
# 1        0        0  ...     3497     3497     3497    3497    3497    3497
# 2        0        0  ...     6875     6875     6875    6875    6875    6875
# 3        0        0  ...      153      153      153     153     153     153
# 4        0        0  ...     1900     1900     1900    1900    1900    1900
#
#    6/4/22  6/5/22  6/6/22  6/7/22
# 0    7708    7708    7709    7709
# 1    3497    3497    3497    3497
# 2    6875    6875    6875    6875
# 3     153     153     153     153
# 4    1900    1900    1900    1900
#
# [5 rows x 872 columns]

# %% [markdown]
# We can change the pivoted (wide) dataframe format and consolidate all data altogether.

# %%
names = ['confirmed', 'recovered', 'deaths']
for i, df in enumerate(datasets):
    df = df.melt(id_vars=['country', 'state', 'lat', 'long'], 
                 var_name='date', value_name=names[i])
    df['date'] = pd.to_datetime(df['date'])
    datasets[i] = df
    
confirmed_l, recovered_l, deaths_l = datasets

# %%
all_data = confirmed_l.merge(
    recovered_l, on=['country', 'state', 'lat', 'long', 'date'])
all_data = all_data.merge(
    deaths_l, on=['country', 'state', 'lat', 'long', 'date'])
all_data
# Out:
#                      country state        lat        long       date  \
# 0                Afghanistan   NaN  33.939110   67.709953 2020-01-22
# 1                    Albania   NaN  41.153300   20.168300 2020-01-22
# 2                    Algeria   NaN  28.033900    1.659600 2020-01-22
# 3                    Andorra   NaN  42.506300    1.521800 2020-01-22
# 4                     Angola   NaN -11.202700   17.873900 2020-01-22
# ...                      ...   ...        ...         ...        ...
# 229147    West Bank and Gaza   NaN  31.952200   35.233200 2022-06-07
# 229148  Winter Olympics 2022   NaN  39.904200  116.407400 2022-06-07
# 229149                 Yemen   NaN  15.552727   48.516388 2022-06-07
# 229150                Zambia   NaN -13.133897   27.849332 2022-06-07
# 229151              Zimbabwe   NaN -19.015438   29.154857 2022-06-07
#
#         confirmed  recovered  deaths
# 0               0          0       0
# 1               0          0       0
# 2               0          0       0
# 3               0          0       0
# 4               0          0       0
# ...           ...        ...     ...
# 229147     657879          0    5660
# 229148        535          0       0
# 229149      11822          0    2149
# 229150     322562          0    3988
# 229151     253637          0    5515
#
# [229152 rows x 8 columns]

# %%
country = all_data.groupby(['country', 'date']).sum().reset_index()
country = country.drop(['lat', 'long'], axis=1)

country_total = country.groupby('country').agg(
    {'confirmed':'sum', 'recovered':'sum', 'deaths':'sum'}).reset_index()
country_total
# Out:
#                   country  confirmed  recovered   deaths
# 0             Afghanistan   75359610   18289880  3274026
# 1                 Albania   96711349   22652652  1502481
# 2                 Algeria  108517652   25670233  3009489
# 3                 Andorra   11782868    3085649    83845
# 4                  Angola   31593946    5895800   704094
# ..                    ...        ...        ...      ...
# 190    West Bank and Gaza  221517536   57608773  2188023
# 191  Winter Olympics 2022      67337          0        0
# 192                 Yemen    4602337     772497   922585
# 193                Zambia  104208951   21852796  1525792
# 194              Zimbabwe   69327714    8779035  1918944
#
# [195 rows x 4 columns]

# %% [markdown]
# We can count total of all 3 values from start of data entry until today.

# %%
totals = country_total[['confirmed', 'recovered', 'deaths']].sum(axis=0)
print(totals)
# Out:
# confirmed    144807049634
# recovered     23208807971
# deaths         2569063047
# dtype: int64

# %% [markdown]
# ## Visualization
# We can visualize totals and severity of COVID-19 per country from above dataframes.

# %%
top_deaths = country_total.sort_values('deaths', ascending=False).head(10)

plt.figure(figsize=(12,7))
sns.set_theme()
sns.barplot(x=top_deaths['country'], y=top_deaths['deaths'])
plt.title('Top 10 Affected Countries')
plt.xlabel('Country')
plt.ylabel('Deaths')
plt.show()

# %%
top_confirmed = country_total.sort_values('confirmed', ascending=False).head(10)

plt.figure(figsize=(12,7))
sns.set_theme()
sns.barplot(x=top_confirmed['country'], y=top_confirmed['confirmed'])
plt.title('Top 10 Affected Countries')
plt.xlabel('Country')
plt.ylabel('Confirmed')
plt.show()

# %% [markdown]
# Then, we can view the confirmed, recovered, and death numbers from beginning to latest data entry.

# %%
total_by_date = country.groupby('date').sum()

sns.set_theme()
plt.figure(figsize=(12,7))
plt.plot(total_by_date['confirmed'], label='Confirmed')
plt.plot(total_by_date['recovered'], label='Recovered')
plt.plot(total_by_date['deaths'], label='Deaths')
plt.xlabel('Date')
plt.ylabel('Cases')
plt.title('COVID-19 Case Numbers Until Present')
plt.legend()
plt.show()

# %% [markdown]
# Finally, we are able to graphically visualize severity per country in terms of confirmed cases using a map.

# %%
m = folium.Map(location=(2,0), tiles='cartodbpositron', zoom_start=2, max_zoom=6, min_zoom=2)
confirmed.dropna(subset=['lat','long'], inplace=True)

for i in range(len(confirmed)):
    folium.Circle(
        location=[confirmed.lat.iloc[i], confirmed.long.iloc[i]],
        fill=True,
        fill_color='red',
        color='red',
        radius=int(np.log(confirmed.iloc[i,-1]+1.00001))*10000,
        popup=('{} ({})'.format(
            confirmed.country.iloc[i],
            confirmed.iloc[i,-1]))).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_72771db5251c577d2613a3ee9c7eae5b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_72771db5251c577d2613a3ee9c7eae5b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_72771db5251c577d2613a3ee9c7eae5b = L.map(
#                 &quot;map_72771db5251c577d2613a3ee9c7eae5b&quot;,
#                 {
#                     center: [2.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d116643bad79a80c4fba2af0009e7d30 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 6, &quot;maxZoom&quot;: 6, &quot;minZoom&quot;: 2, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_72771db5251c577d2613a3ee9c7eae5b);
#
#
#             var circle_7b41f668ede7314b873d3d8054f80ed4 = L.circle(
#                 [33.93911, 67.709953],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 120000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_72771db5251c577d2613a3ee9c7eae5b);
#
#
#         var popup_f432623d9c32b86a8ecaac44cdf1a153 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_18547752d00b8a5f6672cb920d72199c = $(`&lt;div id=&quot;html_18547752d00b8a5f6672cb920d72199c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Afghanistan (180741)&lt;/div&gt;`)[0];
#             popup_f432623d9c32b86a8ecaac44cdf1a153.setContent(html_18547752d00b8a5f6672cb920d72199c);
#
#
#         circle_7b41f668ede7314b873d3d8054f80ed4.bindPopup(popup_f432623d9c32b86a8ecaac44cdf1a153)
#         ;
#
#
#
#
#             var circle_7ce8b85a735b7a6740e89b96f96b0d6c = L.circle(
#                 [41.1533, 20.1683],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 120000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_72771db5251c577d2613a3ee9c7eae5b);
#
#
#         var popup_dccf415ee58f4e824bbb7840cfaa2359 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_79764e9ede6166dea9079afc349a9f55 = $(`&lt;div id=&quot;html_79764e9ede6166dea9079afc349a9f55&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Albania (276468)&lt;/div&gt;`)[0];
#             popup_dccf415ee58f4e824bbb7840cfaa2359.setContent(html_79764e9ede6166dea9079afc349a9f55);
#
#
#         circle_7ce8b85a735b7a6740e89b96f96b0d6c.bindPopup(popup_dccf415ee58f4e824bbb7840cfaa2359)
#         ;
#
#
#
#
#             var circle_a7f03cee2c96a5d4ff1a083995848078 = L.circle(
#                 [28.0339, 1.6596],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 120000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_72771db5251c577d2613a3ee9c7eae5b);
#
#
#         var popup_7bd71e7fdcdc1cefc83fbda71144aec4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_61fd2bc1e8fdf965bf4e358f166c7f74 = $(`&lt;div id=&quot;html_61fd2bc1e8fdf965bf4e358f166c7f74&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Algeria (265904)&lt;/div&gt;`)[0];
#             popup_7bd71e7fdcdc1cefc83fbda71144aec4.setContent(html_61fd2bc1e8fdf965bf4e358f166c7f74);
#
#
#         circle_a7f03cee2c96a5d4ff1a083995848078.bindPopup(popup_7bd71e7fdcdc1cefc83fbda71144aec4)
#         ;
#
#
#
#
#             var circle_55d9c5d23aa4da339900b0efe9548199 = L.circle(
#                 [42.5063, 1.5218],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &q
